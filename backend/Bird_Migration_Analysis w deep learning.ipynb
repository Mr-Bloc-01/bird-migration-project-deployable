# %% [markdown]
# # Custom Bird Migration Data Analysis

# %% [markdown]
# ## Imports

# %%
from sklearn.model_selection import train_test_split, learning_curve
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

import pickle
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# Allow the use of custom functions in the utils folder if needed
import sys
import os

# Add the parent directory to the Python path
sys.path.append(os.path.abspath('..'))

# %% [markdown]
# ## Cleaning the Dataset

# %% [markdown]
# ### Initializing Dataframe

# %%
# Initialize dataframe to read
df = pd.read_csv('data/bird_migration_NEW.csv')

# Display dataframe information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1301 entries, 0 to 1300
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   year             1301 non-null   int64
#  1    month           1301 non-null   int64
#  2    day             1301 non-null   int64
#  3    latitude        1301 non-null   float64
#  4    longitude       1301 non-null   float64
#  5    temperature     1301 non-null   int64
#  6    wind_speed      1301 non-null   int64
#  7    wind_direction  1301 non-null   int64
# dtypes: float64(2), int64(6)
# memory usage: 81.4 KB

# %% [markdown]
# ### Cleaning the dataset

# %%
# Remove leading and trailing whitespaces from column names
df.columns = df.columns.str.strip()

# Remove leading and trailing whitespaces from each cell
for col in df.columns:
    if pd.api.types.is_string_dtype(df[col]):
        df[col] = df[col].str.strip()

# %% [markdown]
# # Basic Machine Learning Model Training & Analysis

# %% [markdown]
# ### Removing Outliers

# %%
# df = df[df['year'] != 2014]

# %% [markdown]
# ### Performing a train test split

# %%
# Perform a train test split
#Initialize features and targets
features = df[['month', 'day', 'temperature', 'wind_speed']]
target = df['latitude']

# Initialize Training and Test Sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size = 0.2, random_state = 42)

# %% [markdown]
# ### Initialize Machine Learning Models

# %%
# Initilize different bacic machine learning models
model_linear = LinearRegression()
model_rf = RandomForestRegressor()
model_svr = SVR()
model_knn = KNeighborsRegressor(n_neighbors = 2)
model_gb = GradientBoostingRegressor() 
model_dt = DecisionTreeRegressor()

# Train the models
model_linear.fit(X_train, y_train)
model_rf.fit(X_train, y_train)
model_svr.fit(X_train, y_train)
model_knn.fit(X_train, y_train)
model_gb.fit(X_train, y_train)
model_dt.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
# Train the models
model_linear.fit(X_train, y_train)
model_rf.fit(X_train, y_train)
model_svr.fit(X_train, y_train)
model_knn.fit(X_train, y_train)
model_gb.fit(X_train, y_train)
model_dt.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %% [markdown]
# ### Make Predictions and Evaluate Performance
#
# The Mean Squared Error(MSE) measures the average squared difference between the rpedicted values and the actual values. It quantifies how close the predictions are to the actual outcome.
# $$MSE = \frac{1}{n} \sum_{i=1}^{n} (y_i - \hat{y}_i)^2$$
#
# The $R^2$ represents the proportion of the variance in the target variable. Mesaures the 'goodness of fit' of the model. 1 Indicates that the model explains 100% of the variance in the target variable. 0 indicates that the models explains none of the variance and the predictions are **as good as the mean of the target variable**. An $R^2$ < 0 indicates that the model performs worse than a simple mean-bsaed prediction.
# $$R^2 = 1 - \frac{SS_{res}}{SS_{tot}}$$

# %% [markdown]
# #### Making predictions on Test Set

# %%
# Import methods created in the utils folder
from utils.metrics import evaluate_model

# Make predictions
y_pred_linear = model_linear.predict(X_test)
y_pred_rf = model_rf.predict(X_test)
y_pred_svr = model_svr.predict(X_test)
y_pred_knn = model_knn.predict(X_test)
y_pred_gb = model_gb.predict(X_test)
y_pred_dt = model_dt.predict(X_test)

# %% [markdown]
# #### Evaluating Machine Learning Models

# %%
# Evaluate performance
mse_linear, r2_linear = evaluate_model(y_test, y_pred_linear)
mse_rf, r2_rf = evaluate_model(y_test, y_pred_rf)
mse_svr, r2_svr = evaluate_model(y_test, y_pred_svr)
mse_knn, r2_knn = evaluate_model(y_test, y_pred_knn)
mse_gb, r2_gb = evaluate_model(y_test, y_pred_gb)
mse_dt, r2_dt = evaluate_model(y_test, y_pred_dt)

r2_linear = r2_score(y_test, y_pred_linear)
r2_rf = r2_score(y_test, y_pred_rf)
r2_svr = r2_score(y_test, y_pred_svr)
r2_knn = r2_score(y_test, y_pred_knn)
r2_gb = r2_score(y_test, y_pred_gb)
r2_dt = r2_score(y_test, y_pred_dt)

# Print the results
print("Linear Regression Performance:")
print(f"Mean Squared Error: {mse_linear}")
print(f"R^2 Score: {r2_linear}")

print("\nRandom Forest Regressor Performance:")
print(f"Mean Squared Error: {mse_rf}")
print(f"R^2 Score: {r2_rf}")

print("\nSupport Vector Regressor Performance:")
print(f"Mean Squared Error: {mse_svr}")
print(f"R^2 Score: {r2_svr}")

print("\nK-Nearest Neighbors Regressor Performance:")
print(f"Mean Squared Error: {mse_knn}")
print(f"R^2 Score: {r2_knn}")

print("\nGradient Boosting Regressor Performance:")
print(f"Mean Squared Error: {mse_gb}")
print(f"R^2 Score: {r2_gb}")

print("\nDecision Tree Regressor Performance:")
print(f"Mean Squared Error: {mse_dt}")
print(f"R^2 Score: {r2_dt}")
# Out:
# Linear Regression Performance:
# Mean Squared Error: 240.77546398986905
# R^2 Score: 0.5659515445691268
#
# Random Forest Regressor Performance:
# Mean Squared Error: 52.977401284351615
# R^2 Score: 0.9044970828041602
#
# Support Vector Regressor Performance:
# Mean Squared Error: 185.9354753661746
# R^2 Score: 0.6648121675060337
#
# K-Nearest Neighbors Regressor Performance:
# Mean Squared Error: 98.78331417624521
# R^2 Score: 0.8219222829850055
#
# Gradient Boosting Regressor Performance:
# Mean Squared Error: 54.087854849144556
# R^2 Score: 0.902495256510737
#
# Decision Tree Regressor Performance:
# Mean Squared Error: 81.51235313697318
# R^2 Score: 0.853056825677521

# %% [markdown]
# #### Making Predictions
#
# Predictions need to be based on the number of features. This means that if you have 5 features that were used to train the model, you need 5 inputs to make a prediction

# %%
# Example of individual user input
user_input_month = 1
user_input_day = 1
user_input_temp = 24
user_input_wind_speed = 2

# 2018, 01, 01, -5.19, 13.36, 24, 2, 180

# Combine indiividual user input to same format as what was trained
user_input = [[user_input_month, user_input_day, user_input_temp, user_input_wind_speed]]

# Make predictions with each model
y_pred_linear_new = model_linear.predict(user_input)
y_pred_rf_new = model_rf.predict(user_input)
y_pred_svr_new = model_svr.predict(user_input)
y_pred_knn_new = model_knn.predict(user_input)
y_pred_gb_new = model_gb.predict(user_input)
y_pred_dt_new = model_dt.predict(user_input)

# Output predictions
print("Prediction using Linear Regression:")
print(y_pred_linear_new)

print("\nPrediction using Random Forest Regressor:")
print(y_pred_rf_new)

print("\nPrediction using Support Vector Regressor:")
print(y_pred_svr_new)

print("\nPrediction using K-Nearest Neighbors Regressor:")
print(y_pred_knn_new)

print("\nPrediction using Gradient Boosting Regressor:")
print(y_pred_gb_new)

print("\nPrediction using Decision Tree Regressor:")
print(y_pred_dt_new)
# Out:
# Prediction using Linear Regression:
# [6.08394277]
#
# Prediction using Random Forest Regressor:
# [-2.2103]
#
# Prediction using Support Vector Regressor:
# [12.70001284]
#
# Prediction using K-Nearest Neighbors Regressor:
# [-2.86]
#
# Prediction using Gradient Boosting Regressor:
# [1.36162096]
#
# Prediction using Decision Tree Regressor:
# [-5.19]
# d:\Science Fair\2024 - 2025\ML Bird Migration\venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# d:\Science Fair\2024 - 2025\ML Bird Migration\venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# d:\Science Fair\2024 - 2025\ML Bird Migration\venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# d:\Science Fair\2024 - 2025\ML Bird Migration\venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but KNeighborsRegressor was fitted with feature names
#   warnings.warn(
# d:\Science Fair\2024 - 2025\ML Bird Migration\venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# d:\Science Fair\2024 - 2025\ML Bird Migration\venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %% [markdown]
# #### Graphs

# %% [markdown]
# ##### Model Predictions vs. Actual Values

# %%
# Plot predictions vs. actual values
plt.figure(figsize=(14, 7))

# Linear Regression
plt.subplot(2, 3, 1)
plt.scatter(y_test, y_pred_linear, color='blue')
plt.plot(y_test, y_test, color='red', linewidth=2)
plt.xlabel('True Target Values')
plt.ylabel('Predicted Target Values')
plt.title('Linear Regression')

# Random Forest Regressor
plt.subplot(2, 3, 2)
plt.scatter(y_test, y_pred_rf, color='blue')
plt.plot(y_test, y_test, color='red', linewidth=2)
plt.xlabel('True Target Values')
plt.ylabel('Predicted Target Values')
plt.title('Random Forest Regressor')

# Support Vector Regressor
plt.subplot(2, 3, 3)
plt.scatter(y_test, y_pred_svr, color='blue')
plt.plot(y_test, y_test, color='red', linewidth=2)
plt.xlabel('True Target Values')
plt.ylabel('Predicted Target Values')
plt.title('Support Vector Regressor')

# K-Nearest Neighbors Regressor
plt.subplot(2, 3, 4)
plt.scatter(y_test, y_pred_knn, color='blue')
plt.plot(y_test, y_test, color='red', linewidth=2)
plt.xlabel('True Target Values')
plt.ylabel('Predicted Target Values')
plt.title('K-Nearest Neighbors Regressor')

# Gradient Boosting Regressor
plt.subplot(2, 3, 5)
plt.scatter(y_test, y_pred_gb, color='blue')
plt.plot(y_test, y_test, color='red', linewidth=2)
plt.xlabel('True Target Values')
plt.ylabel('Predicted Target Values')
plt.title('Gradient Boosting Regressor')

# Decision Tree Regressor
plt.subplot(2, 3, 6)
plt.scatter(y_test, y_pred_dt, color='blue')
plt.plot(y_test, y_test, color='red', linewidth=2)
plt.xlabel('True Target Values')
plt.ylabel('Predicted Target Values')
plt.title('Decision Tree Regressor')

plt.tight_layout()
plt.show()

# %%
from utils.plot_learning_curve import plot_learning_curve

# Plot learning curves for each model
plot_learning_curve(model_linear, X_train, y_train, title="Linear Regression Learning Curve")
plot_learning_curve(model_rf, X_train, y_train, title="Random Forest Learning Curve")
plot_learning_curve(model_svr, X_train, y_train, title="Support Vector Regressor Learning Curve")
plot_learning_curve(model_knn, X_train, y_train, title="K-Nearest Neighbors Learning Curve")
plot_learning_curve(model_gb, X_train, y_train, title="Gradient Boosting Learning Curve")
plot_learning_curve(model_dt, X_train, y_train, title="Decision Tree Learning Curve")

# %% [markdown]
# #### Save with Pickle

# %%
with open("models/DT_Model_Latitude.pkl", "wb") as handle:
    pickle.dump(model_dt, handle, protocol=pickle.HIGHEST_PROTOCOL)

# model_dt.save_weights()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 with open("/models/DT_Model_Latitude.h5", "wb") as handle:
#       2     pickle.dump(model_dt, handle, protocol=pickle.HIGHEST_PROTOCOL)
#
# File d:\Science Fair\2024 - 2025\ML Bird Migration\venv\Lib\site-packages\IPython\core\interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/models/DT_Model_Latitude.h5'

# %% [markdown]
# ### Do Same Training for Longitude

# %%
# Perform a train test split
#Initialize features and targets
features = df[['month', 'day', 'temperature', 'wind_speed']]
target = df['longitude']

# Initialize Training and Test Sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size = 0.2, random_state = 42)

# %%
# Train the models
model_linear.fit(X_train, y_train)
model_rf.fit(X_train, y_train)
model_svr.fit(X_train, y_train)
model_knn.fit(X_train, y_train)
model_gb.fit(X_train, y_train)
model_dt.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
# Initilize different bacic machine learning models
model_linear = LinearRegression()
model_rf = RandomForestRegressor()
model_svr = SVR()
model_knn = KNeighborsRegressor(n_neighbors = 2)
model_gb = GradientBoostingRegressor() 
model_dt = DecisionTreeRegressor()

# Train the models
model_linear.fit(X_train, y_train)
model_rf.fit(X_train, y_train)
model_svr.fit(X_train, y_train)
model_knn.fit(X_train, y_train)
model_gb.fit(X_train, y_train)
model_dt.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
# Import methods created in the utils folder
from utils.metrics import evaluate_model

# Make predictions
y_pred_linear = model_linear.predict(X_test)
y_pred_rf = model_rf.predict(X_test)
y_pred_svr = model_svr.predict(X_test)
y_pred_knn = model_knn.predict(X_test)
y_pred_gb = model_gb.predict(X_test)
y_pred_dt = model_dt.predict(X_test)

# %%
# Evaluate performance
mse_linear, r2_linear = evaluate_model(y_test, y_pred_linear)
mse_rf, r2_rf = evaluate_model(y_test, y_pred_rf)
mse_svr, r2_svr = evaluate_model(y_test, y_pred_svr)
mse_knn, r2_knn = evaluate_model(y_test, y_pred_knn)
mse_gb, r2_gb = evaluate_model(y_test, y_pred_gb)
mse_dt, r2_dt = evaluate_model(y_test, y_pred_dt)

r2_linear = r2_score(y_test, y_pred_linear)
r2_rf = r2_score(y_test, y_pred_rf)
r2_svr = r2_score(y_test, y_pred_svr)
r2_knn = r2_score(y_test, y_pred_knn)
r2_gb = r2_score(y_test, y_pred_gb)
r2_dt = r2_score(y_test, y_pred_dt)

# Print the results
print("Linear Regression Performance:")
print(f"Mean Squared Error: {mse_linear}")
print(f"R^2 Score: {r2_linear}")

print("\nRandom Forest Regressor Performance:")
print(f"Mean Squared Error: {mse_rf}")
print(f"R^2 Score: {r2_rf}")

print("\nSupport Vector Regressor Performance:")
print(f"Mean Squared Error: {mse_svr}")
print(f"R^2 Score: {r2_svr}")

print("\nK-Nearest Neighbors Regressor Performance:")
print(f"Mean Squared Error: {mse_knn}")
print(f"R^2 Score: {r2_knn}")

print("\nGradient Boosting Regressor Performance:")
print(f"Mean Squared Error: {mse_gb}")
print(f"R^2 Score: {r2_gb}")

print("\nDecision Tree Regressor Performance:")
print(f"Mean Squared Error: {mse_dt}")
print(f"R^2 Score: {r2_dt}")
# Out:
# Linear Regression Performance:
# Mean Squared Error: 76.06194525702817
# R^2 Score: 0.12570770761457084
#
# Random Forest Regressor Performance:
# Mean Squared Error: 61.24681855373195
# R^2 Score: 0.2959998431053943
#
# Support Vector Regressor Performance:
# Mean Squared Error: 72.55493655649754
# R^2 Score: 0.16601893901736287
#
# K-Nearest Neighbors Regressor Performance:
# Mean Squared Error: 81.7891511494253
# R^2 Score: 0.059876470302578144
#
# Gradient Boosting Regressor Performance:
# Mean Squared Error: 60.6793217120155
# R^2 Score: 0.3025229225900058
#
# Decision Tree Regressor Performance:
# Mean Squared Error: 90.10869404001701
# R^2 Score: -0.03575232542220963

# %%
# Example of individual user input
user_input_month = 1
user_input_day = 1
user_input_temp = 24
user_input_wind_speed = 2

# 2018, 01, 01, -5.19, 13.36, 24, 2, 180

# Combine indiividual user input to same format as what was trained
user_input = [[user_input_month, user_input_day, user_input_temp, user_input_wind_speed]]

# Make predictions with each model
y_pred_linear_new = model_linear.predict(user_input)
y_pred_rf_new = model_rf.predict(user_input)
y_pred_svr_new = model_svr.predict(user_input)
y_pred_knn_new = model_knn.predict(user_input)
y_pred_gb_new = model_gb.predict(user_input)
y_pred_dt_new = model_dt.predict(user_input)

# Output predictions
print("Prediction using Linear Regression:")
print(y_pred_linear_new)

print("\nPrediction using Random Forest Regressor:")
print(y_pred_rf_new)

print("\nPrediction using Support Vector Regressor:")
print(y_pred_svr_new)

print("\nPrediction using K-Nearest Neighbors Regressor:")
print(y_pred_knn_new)

print("\nPrediction using Gradient Boosting Regressor:")
print(y_pred_gb_new)

print("\nPrediction using Decision Tree Regressor:")
print(y_pred_dt_new)
# Out:
# Prediction using Linear Regression:
# [18.66744013]
#
# Prediction using Random Forest Regressor:
# [16.44061667]
#
# Prediction using Support Vector Regressor:
# [19.45822264]
#
# Prediction using K-Nearest Neighbors Regressor:
# [15.33]
#
# Prediction using Gradient Boosting Regressor:
# [19.87762951]
#
# Prediction using Decision Tree Regressor:
# [13.36]
# d:\Science Fair\2024 - 2025\ML Bird Migration\venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# d:\Science Fair\2024 - 2025\ML Bird Migration\venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# d:\Science Fair\2024 - 2025\ML Bird Migration\venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# d:\Science Fair\2024 - 2025\ML Bird Migration\venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but KNeighborsRegressor was fitted with feature names
#   warnings.warn(
# d:\Science Fair\2024 - 2025\ML Bird Migration\venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# d:\Science Fair\2024 - 2025\ML Bird Migration\venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
# Plot predictions vs. actual values
plt.figure(figsize=(14, 7))

# Linear Regression
plt.subplot(2, 3, 1)
plt.scatter(y_test, y_pred_linear, color='blue')
plt.plot(y_test, y_test, color='red', linewidth=2)
plt.xlabel('True Target Values')
plt.ylabel('Predicted Target Values')
plt.title('Linear Regression')

# Random Forest Regressor
plt.subplot(2, 3, 2)
plt.scatter(y_test, y_pred_rf, color='blue')
plt.plot(y_test, y_test, color='red', linewidth=2)
plt.xlabel('True Target Values')
plt.ylabel('Predicted Target Values')
plt.title('Random Forest Regressor')

# Support Vector Regressor
plt.subplot(2, 3, 3)
plt.scatter(y_test, y_pred_svr, color='blue')
plt.plot(y_test, y_test, color='red', linewidth=2)
plt.xlabel('True Target Values')
plt.ylabel('Predicted Target Values')
plt.title('Support Vector Regressor')

# K-Nearest Neighbors Regressor
plt.subplot(2, 3, 4)
plt.scatter(y_test, y_pred_knn, color='blue')
plt.plot(y_test, y_test, color='red', linewidth=2)
plt.xlabel('True Target Values')
plt.ylabel('Predicted Target Values')
plt.title('K-Nearest Neighbors Regressor')

# Gradient Boosting Regressor
plt.subplot(2, 3, 5)
plt.scatter(y_test, y_pred_gb, color='blue')
plt.plot(y_test, y_test, color='red', linewidth=2)
plt.xlabel('True Target Values')
plt.ylabel('Predicted Target Values')
plt.title('Gradient Boosting Regressor')

# Decision Tree Regressor
plt.subplot(2, 3, 6)
plt.scatter(y_test, y_pred_dt, color='blue')
plt.plot(y_test, y_test, color='red', linewidth=2)
plt.xlabel('True Target Values')
plt.ylabel('Predicted Target Values')
plt.title('Decision Tree Regressor')

plt.tight_layout()
plt.show()

# %%
with open("models/DT_Model_Longitude.pkl", "wb") as handle:
    pickle.dump(model_dt, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ##### Learning Curves

# %%
from utils.plot_learning_curve import plot_learning_curve

# Plot learning curves for each model
plot_learning_curve(model_linear, X_train, y_train, title="Linear Regression Learning Curve")
plot_learning_curve(model_rf, X_train, y_train, title="Random Forest Learning Curve")
plot_learning_curve(model_svr, X_train, y_train, title="Support Vector Regressor Learning Curve")
plot_learning_curve(model_knn, X_train, y_train, title="K-Nearest Neighbors Learning Curve")
plot_learning_curve(model_gb, X_train, y_train, title="Gradient Boosting Learning Curve")
plot_learning_curve(model_dt, X_train, y_train, title="Decision Tree Learning Curve")

# %% [markdown]
# ##### Pair Plots for all Columns

# %%
# Use seaborn to show the relationhsip of every column and visulize it
sns.pairplot(df)
plt.show()

# %% [markdown]
# ##### Correlaion Matrix
#
# Helps identify **Linear relationships** between variables

# %%
# Need to first make sure that all datatypes of the dataframe are numerical
# You can do this by only chossing the numerical columns OR using a labelencoder and convert the object datatypes to numerical

# Select only the numeric columns
numeric_df = df.select_dtypes(include=[float, int])

# Compute the correlation matrix
corr_matrix = numeric_df.corr()

# Plot the correlation matrix
plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# # Deep Learning Models

# %% [markdown]
# ## Initialize new target and features for Deep Learning

# %%
# Initialize features and targets
features = df[['month', 'day', 'temperature', 'wind_speed']]
targets = df[['latitude', 'longitude']]

# Split dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, targets, test_size = 0.2, random_state = 42)

# Standardize features
scaler_X = StandardScaler()
X_train = scaler_X.fit_transform(X_train)
X_test = scaler_X.transform(X_test)

# Standardize targets (important for deep learning)
scaler_y = StandardScaler()
y_train = scaler_y.fit_transform(y_train)
y_test = scaler_y.transform(y_test)

# %% [markdown]
# ## Build the Deep Learning Model - Sequential Model

# %%
# Initialize the model
model = Sequential()

# Add layers
model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))  # Input layer
model.add(Dense(64, activation='relu'))  # Hidden layer
model.add(Dense(2))  # Output layer (2 outputs for longitude and latitude)

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# d:\Science Fair\2024 - 2025\ML Bird Migration\venv\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# ## Train the Deep Learning Model

# %%
# Train the model
history = model.fit(X_train, y_train, epochs = 1000, batch_size = 8, validation_split = 0.2, verbose = 1)
# Out:
# Epoch 1/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.9543 - val_loss: 0.6784
# Epoch 2/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step - loss: 0.6403 - val_loss: 0.6123
# Epoch 3/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 726us/step - loss: 0.5219 - val_loss: 0.5676
# Epoch 4/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 726us/step - loss: 0.5179 - val_loss: 0.5637
# Epoch 5/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 719us/step - loss: 0.5120 - val_loss: 0.5548
# Epoch 6/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 712us/step - loss: 0.5314 - val_loss: 0.5527
# Epoch 7/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step - loss: 0.4843 - val_loss: 0.5273
# Epoch 8/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step - loss: 0.4504 - val_loss: 0.5218
# Epoch 9/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step - loss: 0.4232 - val_loss: 0.5182
# Epoch 10/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step - loss: 0.4597 - val_loss: 0.5519
# Epoch 11/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step - loss: 0.3902 - val_loss: 0.5268
# Epoch 12/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step - loss: 0.4516 - val_loss: 0.5364
# Epoch 13/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step - loss: 0.4678 - val_loss: 0.5237
# Epoch 14/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 711us/step - loss: 0.4095 - val_loss: 0.5209
# Epoch 15/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step - loss: 0.4370 - val_loss: 0.5035
# Epoch 16/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step - loss: 0.4413 - val_loss: 0.5289
# Epoch 17/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step - loss: 0.3905 - val_loss: 0.5113
# Epoch 18/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 727us/step - loss: 0.4281 - val_loss: 0.5122
# Epoch 19/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 720us/step - loss: 0.4018 - val_loss: 0.5181
# Epoch 20/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 711us/step - loss: 0.4190 - val_loss: 0.5295
# Epoch 21/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step - loss: 0.4081 - val_loss: 0.5024
# Epoch 22/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 727us/step - loss: 0.4649 - val_loss: 0.5196
# Epoch 23/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step - loss: 0.3651 - val_loss: 0.5222
# Epoch 24/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step - loss: 0.3686 - val_loss: 0.5180
# Epoch 25/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 728us/step - loss: 0.3941 - val_loss: 0.5308
# Epoch 26/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step - loss: 0.4348 - val_loss: 0.5065
# Epoch 27/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step - loss: 0.3508 - val_loss: 0.5413
# Epoch 28/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step - loss: 0.3937 - val_loss: 0.4927
# Epoch 29/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step - loss: 0.3833 - val_loss: 0.5028
# Epoch 30/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 711us/step - loss: 0.3675 - val_loss: 0.5050
# Epoch 31/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 709us/step - loss: 0.3804 - val_loss: 0.5266
# Epoch 32/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step - loss: 0.4098 - val_loss: 0.4941
# Epoch 33/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step - loss: 0.3479 - val_loss: 0.5348
# Epoch 34/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 865us/step - loss: 0.3736 - val_loss: 0.4860
# Epoch 35/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 688us/step - loss: 0.3991 - val_loss: 0.5046
# Epoch 36/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 712us/step - loss: 0.3935 - val_loss: 0.5004
# Epoch 37/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step - loss: 0.3593 - val_loss: 0.5153
# Epoch 38/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 720us/step - loss: 0.3827 - val_loss: 0.5089
# Epoch 39/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 735us/step - loss: 0.3855 - val_loss: 0.5003
# Epoch 40/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 720us/step - loss: 0.3858 - val_loss: 0.4883
# Epoch 41/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step - loss: 0.3652 - val_loss: 0.5240
# Epoch 42/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 723us/step - loss: 0.3651 - val_loss: 0.5047
# Epoch 43/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 719us/step - loss: 0.3665 - val_loss: 0.4948
# Epoch 44/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 719us/step - loss: 0.3989 - val_loss: 0.4960
# Epoch 45/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 736us/step - loss: 0.3945 - val_loss: 0.5451
# Epoch 46/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 677us/step - loss: 0.3660 - val_loss: 0.5056
# Epoch 47/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 711us/step - loss: 0.3509 - val_loss: 0.4966
# Epoch 48/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step - loss: 0.3447 - val_loss: 0.4995
# Epoch 49/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step - loss: 0.3711 - val_loss: 0.5049
# Epoch 50/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 723us/step - loss: 0.3465 - val_loss: 0.4974
# Epoch 51/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 720us/step - loss: 0.3410 - val_loss: 0.4889
# Epoch 52/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 727us/step - loss: 0.2935 - val_loss: 0.4895
# Epoch 53/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step - loss: 0.3713 - val_loss: 0.4974
# Epoch 54/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 706us/step - loss: 0.3399 - val_loss: 0.5221
# Epoch 55/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step - loss: 0.3577 - val_loss: 0.4879
# Epoch 56/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 677us/step - loss: 0.3487 - val_loss: 0.4980
# Epoch 57/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 683us/step - loss: 0.3119 - val_loss: 0.4998
# Epoch 58/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 710us/step - loss: 0.3511 - val_loss: 0.4920
# Epoch 59/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 685us/step - loss: 0.3178 - val_loss: 0.5186
# Epoch 60/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 710us/step - loss: 0.3323 - val_loss: 0.5100
# Epoch 61/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step - loss: 0.3461 - val_loss: 0.4956
# Epoch 62/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step - loss: 0.3386 - val_loss: 0.5073
# Epoch 63/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step - loss: 0.3121 - val_loss: 0.5039
# Epoch 64/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - loss: 0.3504 - val_loss: 0.4988
# Epoch 65/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step - loss: 0.3206 - val_loss: 0.5056
# Epoch 66/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 715us/step - loss: 0.2912 - val_loss: 0.5056
# Epoch 67/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 716us/step - loss: 0.3237 - val_loss: 0.5043
# Epoch 68/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 722us/step - loss: 0.3403 - val_loss: 0.4971
# Epoch 69/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step - loss: 0.3632 - val_loss: 0.4868
# Epoch 70/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 784us/step - loss: 0.2925 - val_loss: 0.5064
# Epoch 71/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step - loss: 0.3300 - val_loss: 0.5078
# Epoch 72/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 709us/step - loss: 0.3689 - val_loss: 0.5128
# Epoch 73/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 707us/step - loss: 0.3325 - val_loss: 0.5220
# Epoch 74/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step - loss: 0.2913 - val_loss: 0.5058
# Epoch 75/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step - loss: 0.3485 - val_loss: 0.5086
# Epoch 76/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step - loss: 0.3406 - val_loss: 0.4998
# Epoch 77/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 727us/step - loss: 0.3439 - val_loss: 0.5043
# Epoch 78/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step - loss: 0.3403 - val_loss: 0.4997
# Epoch 79/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 733us/step - loss: 0.3006 - val_loss: 0.5174
# Epoch 80/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 818us/step - loss: 0.2988 - val_loss: 0.5254
# Epoch 81/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 724us/step - loss: 0.2899 - val_loss: 0.5243
# Epoch 82/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step - loss: 0.3209 - val_loss: 0.5087
# Epoch 83/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step - loss: 0.3195 - val_loss: 0.5098
# Epoch 84/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step - loss: 0.3267 - val_loss: 0.5063
# Epoch 85/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step - loss: 0.3410 - val_loss: 0.4998
# Epoch 86/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 727us/step - loss: 0.2820 - val_loss: 0.5288
# Epoch 87/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step - loss: 0.3294 - val_loss: 0.5162
# Epoch 88/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 686us/step - loss: 0.3105 - val_loss: 0.5184
# Epoch 89/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step - loss: 0.3515 - val_loss: 0.5027
# Epoch 90/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 736us/step - loss: 0.2972 - val_loss: 0.4937
# Epoch 91/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 706us/step - loss: 0.2980 - val_loss: 0.5092
# Epoch 92/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 778us/step - loss: 0.3004 - val_loss: 0.5097
# Epoch 93/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step - loss: 0.3056 - val_loss: 0.5026
# Epoch 94/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 716us/step - loss: 0.2913 - val_loss: 0.5081
# Epoch 95/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step - loss: 0.3221 - val_loss: 0.5046
# Epoch 96/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 708us/step - loss: 0.3419 - val_loss: 0.5034
# Epoch 97/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step - loss: 0.2731 - val_loss: 0.5064
# Epoch 98/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step - loss: 0.2911 - val_loss: 0.4954
# Epoch 99/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 707us/step - loss: 0.3037 - val_loss: 0.5093
# Epoch 100/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 727us/step - loss: 0.2783 - val_loss: 0.5062
# Epoch 101/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step - loss: 0.2929 - val_loss: 0.5346
# Epoch 102/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 723us/step - loss: 0.3088 - val_loss: 0.5049
# Epoch 103/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 727us/step - loss: 0.3041 - val_loss: 0.5040
# Epoch 104/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 726us/step - loss: 0.2738 - val_loss: 0.5018
# Epoch 105/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step - loss: 0.2796 - val_loss: 0.5057
# Epoch 106/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step - loss: 0.2955 - val_loss: 0.5375
# Epoch 107/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 774us/step - loss: 0.3126 - val_loss: 0.4986
# Epoch 108/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step - loss: 0.2919 - val_loss: 0.4914
# Epoch 109/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 715us/step - loss: 0.2733 - val_loss: 0.5061
# Epoch 110/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 727us/step - loss: 0.2754 - val_loss: 0.5093
# Epoch 111/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step - loss: 0.2470 - val_loss: 0.5056
# Epoch 112/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step - loss: 0.2995 - val_loss: 0.5131
# Epoch 113/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step - loss: 0.3200 - val_loss: 0.5101
# Epoch 114/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 681us/step - loss: 0.2773 - val_loss: 0.5211
# Epoch 115/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step - loss: 0.3018 - val_loss: 0.5042
# Epoch 116/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 688us/step - loss: 0.2794 - val_loss: 0.5197
# Epoch 117/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 834us/step - loss: 0.2864 - val_loss: 0.5064
# Epoch 118/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step - loss: 0.2686 - val_loss: 0.5292
# Epoch 119/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step - loss: 0.2935 - val_loss: 0.5220
# Epoch 120/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step - loss: 0.2591 - val_loss: 0.5270
# Epoch 121/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 711us/step - loss: 0.2969 - val_loss: 0.5069
# Epoch 122/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step - loss: 0.2831 - val_loss: 0.5092
# Epoch 123/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step - loss: 0.2968 - val_loss: 0.5276
# Epoch 124/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step - loss: 0.2504 - val_loss: 0.5137
# Epoch 125/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 720us/step - loss: 0.2503 - val_loss: 0.5165
# Epoch 126/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 727us/step - loss: 0.2645 - val_loss: 0.5223
# Epoch 127/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 692us/step - loss: 0.2782 - val_loss: 0.5208
# Epoch 128/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 716us/step - loss: 0.2858 - val_loss: 0.5074
# Epoch 129/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step - loss: 0.2633 - val_loss: 0.5100
# Epoch 130/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 720us/step - loss: 0.2577 - val_loss: 0.5020
# Epoch 131/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step - loss: 0.2895 - val_loss: 0.5288
# Epoch 132/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 720us/step - loss: 0.2585 - val_loss: 0.5096
# Epoch 133/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 688us/step - loss: 0.2229 - val_loss: 0.5219
# Epoch 134/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 715us/step - loss: 0.2758 - val_loss: 0.5155
# Epoch 135/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - loss: 0.2715 - val_loss: 0.5185
# Epoch 136/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step - loss: 0.2562 - val_loss: 0.5135
# Epoch 137/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step - loss: 0.2861 - val_loss: 0.5203
# Epoch 138/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 781us/step - loss: 0.2808 - val_loss: 0.5176
# Epoch 139/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step - loss: 0.2491 - val_loss: 0.5275
# Epoch 140/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step - loss: 0.2641 - val_loss: 0.5093
# Epoch 141/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step - loss: 0.2742 - val_loss: 0.5155
# Epoch 142/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 726us/step - loss: 0.2744 - val_loss: 0.5278
# Epoch 143/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step - loss: 0.2588 - val_loss: 0.5047
# Epoch 144/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 766us/step - loss: 0.2366 - val_loss: 0.5262
# Epoch 145/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step - loss: 0.2527 - val_loss: 0.5307
# Epoch 146/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step - loss: 0.2622 - val_loss: 0.5264
# Epoch 147/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 684us/step - loss: 0.2534 - val_loss: 0.5243
# Epoch 148/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step - loss: 0.2661 - val_loss: 0.5497
# Epoch 149/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 711us/step - loss: 0.2690 - val_loss: 0.5345
# Epoch 150/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 719us/step - loss: 0.2368 - val_loss: 0.5211
# Epoch 151/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 710us/step - loss: 0.2915 - val_loss: 0.5280
# Epoch 152/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 716us/step - loss: 0.2605 - val_loss: 0.5241
# Epoch 153/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 713us/step - loss: 0.2856 - val_loss: 0.5107
# Epoch 154/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step - loss: 0.2649 - val_loss: 0.5207
# Epoch 155/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step - loss: 0.2472 - val_loss: 0.5289
# Epoch 156/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step - loss: 0.2589 - val_loss: 0.5282
# Epoch 157/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 719us/step - loss: 0.2333 - val_loss: 0.5270
# Epoch 158/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - loss: 0.2323 - val_loss: 0.5064
# Epoch 159/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step - loss: 0.2188 - val_loss: 0.5262
# Epoch 160/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step - loss: 0.2868 - val_loss: 0.5352
# Epoch 161/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 722us/step - loss: 0.2462 - val_loss: 0.5439
# Epoch 162/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 777us/step - loss: 0.2563 - val_loss: 0.5323
# Epoch 163/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step - loss: 0.2887 - val_loss: 0.5390
# Epoch 164/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 728us/step - loss: 0.2422 - val_loss: 0.5182
# Epoch 165/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 713us/step - loss: 0.2628 - val_loss: 0.5504
# Epoch 166/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step - loss: 0.2593 - val_loss: 0.5261
# Epoch 167/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 707us/step - loss: 0.2429 - val_loss: 0.5624
# Epoch 168/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step - loss: 0.2321 - val_loss: 0.5182
# Epoch 169/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step - loss: 0.2188 - val_loss: 0.5465
# Epoch 170/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 777us/step - loss: 0.2604 - val_loss: 0.5361
# Epoch 171/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 710us/step - loss: 0.2600 - val_loss: 0.5435
# Epoch 172/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 689us/step - loss: 0.2114 - val_loss: 0.5356
# Epoch 173/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 733us/step - loss: 0.2096 - val_loss: 0.5441
# Epoch 174/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 710us/step - loss: 0.2453 - val_loss: 0.5325
# Epoch 175/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step - loss: 0.2404 - val_loss: 0.5362
# Epoch 176/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 685us/step - loss: 0.2590 - val_loss: 0.5244
# Epoch 177/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 724us/step - loss: 0.2475 - val_loss: 0.5339
# Epoch 178/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step - loss: 0.2118 - val_loss: 0.5604
# Epoch 179/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 722us/step - loss: 0.2177 - val_loss: 0.5324
# Epoch 180/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 726us/step - loss: 0.2567 - val_loss: 0.5330
# Epoch 181/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step - loss: 0.1987 - val_loss: 0.5160
# Epoch 182/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step - loss: 0.2351 - val_loss: 0.5253
# Epoch 183/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step - loss: 0.2250 - val_loss: 0.5431
# Epoch 184/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 797us/step - loss: 0.2296 - val_loss: 0.5530
# Epoch 185/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 722us/step - loss: 0.2434 - val_loss: 0.5282
# Epoch 186/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step - loss: 0.2427 - val_loss: 0.5433
# Epoch 187/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step - loss: 0.2346 - val_loss: 0.5402
# Epoch 188/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 735us/step - loss: 0.2387 - val_loss: 0.5215
# Epoch 189/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step - loss: 0.2311 - val_loss: 0.5397
# Epoch 190/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step - loss: 0.2419 - val_loss: 0.5373
# Epoch 191/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step - loss: 0.2432 - val_loss: 0.5285
# Epoch 192/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step - loss: 0.2401 - val_loss: 0.5337
# Epoch 193/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step - loss: 0.2332 - val_loss: 0.5352
# Epoch 194/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 708us/step - loss: 0.2475 - val_loss: 0.5529
# Epoch 195/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step - loss: 0.2261 - val_loss: 0.5582
# Epoch 196/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step - loss: 0.2520 - val_loss: 0.5477
# Epoch 197/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 709us/step - loss: 0.2512 - val_loss: 0.5486
# Epoch 198/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 807us/step - loss: 0.2587 - val_loss: 0.5463
# Epoch 199/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 712us/step - loss: 0.2219 - val_loss: 0.5455
# Epoch 200/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 676us/step - loss: 0.2368 - val_loss: 0.5532
# Epoch 201/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - loss: 0.2112 - val_loss: 0.5376
# Epoch 202/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 708us/step - loss: 0.2491 - val_loss: 0.5528
# Epoch 203/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step - loss: 0.2312 - val_loss: 0.5536
# Epoch 204/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step - loss: 0.2121 - val_loss: 0.5422
# Epoch 205/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step - loss: 0.2426 - val_loss: 0.5459
# Epoch 206/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step - loss: 0.2425 - val_loss: 0.5768
# Epoch 207/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step - loss: 0.2315 - val_loss: 0.5419
# Epoch 208/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step - loss: 0.2349 - val_loss: 0.5411
# Epoch 209/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step - loss: 0.2272 - val_loss: 0.5695
# Epoch 210/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step - loss: 0.2191 - val_loss: 0.5711
# Epoch 211/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 713us/step - loss: 0.2417 - val_loss: 0.5364
# Epoch 212/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 733us/step - loss: 0.2483 - val_loss: 0.5550
# Epoch 213/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 722us/step - loss: 0.2339 - val_loss: 0.5444
# Epoch 214/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 719us/step - loss: 0.2296 - val_loss: 0.5983
# Epoch 215/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 827us/step - loss: 0.2477 - val_loss: 0.5492
# Epoch 216/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step - loss: 0.2249 - val_loss: 0.5457
# Epoch 217/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 818us/step - loss: 0.2328 - val_loss: 0.5586
# Epoch 218/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 786us/step - loss: 0.2273 - val_loss: 0.5701
# Epoch 219/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step - loss: 0.2199 - val_loss: 0.5467
# Epoch 220/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step - loss: 0.2482 - val_loss: 0.5650
# Epoch 221/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step - loss: 0.2020 - val_loss: 0.5680
# Epoch 222/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step - loss: 0.2364 - val_loss: 0.5560
# Epoch 223/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step - loss: 0.2096 - val_loss: 0.5374
# Epoch 224/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 720us/step - loss: 0.2216 - val_loss: 0.5780
# Epoch 225/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step - loss: 0.2036 - val_loss: 0.5696
# Epoch 226/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step - loss: 0.1945 - val_loss: 0.5315
# Epoch 227/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 713us/step - loss: 0.2403 - val_loss: 0.5623
# Epoch 228/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step - loss: 0.2268 - val_loss: 0.5865
# Epoch 229/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 706us/step - loss: 0.2359 - val_loss: 0.5647
# Epoch 230/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step - loss: 0.2347 - val_loss: 0.5553
# Epoch 231/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step - loss: 0.2097 - val_loss: 0.5591
# Epoch 232/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 724us/step - loss: 0.2312 - val_loss: 0.5704
# Epoch 233/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 710us/step - loss: 0.1933 - val_loss: 0.5612
# Epoch 234/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step - loss: 0.2102 - val_loss: 0.5486
# Epoch 235/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 712us/step - loss: 0.2196 - val_loss: 0.5462
# Epoch 236/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 723us/step - loss: 0.2036 - val_loss: 0.5712
# Epoch 237/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 706us/step - loss: 0.2446 - val_loss: 0.5580
# Epoch 238/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 710us/step - loss: 0.2086 - val_loss: 0.5759
# Epoch 239/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - loss: 0.2258 - val_loss: 0.6072
# Epoch 240/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 726us/step - loss: 0.2456 - val_loss: 0.5535
# Epoch 241/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step - loss: 0.2027 - val_loss: 0.5743
# Epoch 242/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step - loss: 0.2014 - val_loss: 0.5782
# Epoch 243/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step - loss: 0.1763 - val_loss: 0.5486
# Epoch 244/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 728us/step - loss: 0.2208 - val_loss: 0.5889
# Epoch 245/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step - loss: 0.2477 - val_loss: 0.5800
# Epoch 246/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step - loss: 0.2333 - val_loss: 0.5593
# Epoch 247/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 728us/step - loss: 0.2474 - val_loss: 0.5696
# Epoch 248/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step - loss: 0.2175 - val_loss: 0.5597
# Epoch 249/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step - loss: 0.2054 - val_loss: 0.5987
# Epoch 250/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step - loss: 0.1972 - val_loss: 0.5452
# Epoch 251/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 722us/step - loss: 0.1964 - val_loss: 0.6063
# Epoch 252/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step - loss: 0.2222 - val_loss: 0.5688
# Epoch 253/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 711us/step - loss: 0.2013 - val_loss: 0.5859
# Epoch 254/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 707us/step - loss: 0.1836 - val_loss: 0.5766
# Epoch 255/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 716us/step - loss: 0.2260 - val_loss: 0.5908
# Epoch 256/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 716us/step - loss: 0.1756 - val_loss: 0.5794
# Epoch 257/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 709us/step - loss: 0.2089 - val_loss: 0.5669
# Epoch 258/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 713us/step - loss: 0.1939 - val_loss: 0.5767
# Epoch 259/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step - loss: 0.2167 - val_loss: 0.5697
# Epoch 260/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step - loss: 0.2084 - val_loss: 0.5687
# Epoch 261/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step - loss: 0.2125 - val_loss: 0.5763
# Epoch 262/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 708us/step - loss: 0.2015 - val_loss: 0.5690
# Epoch 263/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step - loss: 0.2036 - val_loss: 0.5773
# Epoch 264/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step - loss: 0.2033 - val_loss: 0.5568
# Epoch 265/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 719us/step - loss: 0.2010 - val_loss: 0.5668
# Epoch 266/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 835us/step - loss: 0.1968 - val_loss: 0.5656
# Epoch 267/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 711us/step - loss: 0.2122 - val_loss: 0.5792
# Epoch 268/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 713us/step - loss: 0.2004 - val_loss: 0.5790
# Epoch 269/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 728us/step - loss: 0.1714 - val_loss: 0.5795
# Epoch 270/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 736us/step - loss: 0.2217 - val_loss: 0.5775
# Epoch 271/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 713us/step - loss: 0.2175 - val_loss: 0.5600
# Epoch 272/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step - loss: 0.1954 - val_loss: 0.5841
# Epoch 273/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 719us/step - loss: 0.1960 - val_loss: 0.5835
# Epoch 274/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step - loss: 0.2130 - val_loss: 0.6035
# Epoch 275/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step - loss: 0.2169 - val_loss: 0.5699
# Epoch 276/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step - loss: 0.2303 - val_loss: 0.5666
# Epoch 277/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step - loss: 0.1834 - val_loss: 0.5764
# Epoch 278/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step - loss: 0.2103 - val_loss: 0.5912
# Epoch 279/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step - loss: 0.2082 - val_loss: 0.6367
# Epoch 280/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 688us/step - loss: 0.1988 - val_loss: 0.5694
# Epoch 281/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step - loss: 0.1848 - val_loss: 0.5759
# Epoch 282/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - loss: 0.1944 - val_loss: 0.6018
# Epoch 283/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step - loss: 0.1861 - val_loss: 0.5768
# Epoch 284/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 722us/step - loss: 0.1967 - val_loss: 0.5937
# Epoch 285/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step - loss: 0.2104 - val_loss: 0.5656
# Epoch 286/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step - loss: 0.1876 - val_loss: 0.5813
# Epoch 287/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step - loss: 0.1830 - val_loss: 0.5888
# Epoch 288/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 713us/step - loss: 0.2228 - val_loss: 0.5735
# Epoch 289/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step - loss: 0.2137 - val_loss: 0.5753
# Epoch 290/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step - loss: 0.1947 - val_loss: 0.5847
# Epoch 291/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step - loss: 0.1808 - val_loss: 0.5781
# Epoch 292/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 716us/step - loss: 0.2142 - val_loss: 0.5901
# Epoch 293/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step - loss: 0.1835 - val_loss: 0.6056
# Epoch 294/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step - loss: 0.2100 - val_loss: 0.5802
# Epoch 295/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 723us/step - loss: 0.1630 - val_loss: 0.6133
# Epoch 296/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step - loss: 0.1814 - val_loss: 0.5801
# Epoch 297/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step - loss: 0.2045 - val_loss: 0.6090
# Epoch 298/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step - loss: 0.1928 - val_loss: 0.5950
# Epoch 299/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 692us/step - loss: 0.2011 - val_loss: 0.5722
# Epoch 300/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step - loss: 0.1818 - val_loss: 0.6060
# Epoch 301/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step - loss: 0.1887 - val_loss: 0.6222
# Epoch 302/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step - loss: 0.1910 - val_loss: 0.5809
# Epoch 303/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step - loss: 0.1995 - val_loss: 0.6065
# Epoch 304/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 720us/step - loss: 0.1896 - val_loss: 0.5854
# Epoch 305/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step - loss: 0.1669 - val_loss: 0.5910
# Epoch 306/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step - loss: 0.2189 - val_loss: 0.6128
# Epoch 307/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 671us/step - loss: 0.1976 - val_loss: 0.5903
# Epoch 308/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 715us/step - loss: 0.2293 - val_loss: 0.5965
# Epoch 309/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step - loss: 0.2135 - val_loss: 0.5947
# Epoch 310/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 722us/step - loss: 0.2045 - val_loss: 0.6246
# Epoch 311/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 684us/step - loss: 0.1692 - val_loss: 0.6003
# Epoch 312/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 712us/step - loss: 0.2055 - val_loss: 0.6092
# Epoch 313/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step - loss: 0.1728 - val_loss: 0.5962
# Epoch 314/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 709us/step - loss: 0.2110 - val_loss: 0.6044
# Epoch 315/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step - loss: 0.2085 - val_loss: 0.5996
# Epoch 316/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 692us/step - loss: 0.1917 - val_loss: 0.6228
# Epoch 317/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step - loss: 0.2029 - val_loss: 0.6209
# Epoch 318/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step - loss: 0.2130 - val_loss: 0.6017
# Epoch 319/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 692us/step - loss: 0.1781 - val_loss: 0.6135
# Epoch 320/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 686us/step - loss: 0.2057 - val_loss: 0.6145
# Epoch 321/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step - loss: 0.2246 - val_loss: 0.6006
# Epoch 322/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 711us/step - loss: 0.2138 - val_loss: 0.5993
# Epoch 323/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 760us/step - loss: 0.2257 - val_loss: 0.6037
# Epoch 324/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 720us/step - loss: 0.2101 - val_loss: 0.5893
# Epoch 325/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 707us/step - loss: 0.1789 - val_loss: 0.6016
# Epoch 326/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step - loss: 0.1855 - val_loss: 0.5958
# Epoch 327/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step - loss: 0.1974 - val_loss: 0.6265
# Epoch 328/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 710us/step - loss: 0.2101 - val_loss: 0.6144
# Epoch 329/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 711us/step - loss: 0.1802 - val_loss: 0.6173
# Epoch 330/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step - loss: 0.2031 - val_loss: 0.5981
# Epoch 331/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step - loss: 0.1960 - val_loss: 0.6165
# Epoch 332/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step - loss: 0.1968 - val_loss: 0.6169
# Epoch 333/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step - loss: 0.1719 - val_loss: 0.6419
# Epoch 334/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - loss: 0.1725 - val_loss: 0.6342
# Epoch 335/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step - loss: 0.1899 - val_loss: 0.6189
# Epoch 336/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 670us/step - loss: 0.1737 - val_loss: 0.6220
# Epoch 337/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - loss: 0.1762 - val_loss: 0.6343
# Epoch 338/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step - loss: 0.1747 - val_loss: 0.6142
# Epoch 339/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - loss: 0.2145 - val_loss: 0.5974
# Epoch 340/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step - loss: 0.2006 - val_loss: 0.6380
# Epoch 341/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 712us/step - loss: 0.2008 - val_loss: 0.6442
# Epoch 342/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 678us/step - loss: 0.1801 - val_loss: 0.6271
# Epoch 343/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step - loss: 0.1774 - val_loss: 0.6187
# Epoch 344/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 724us/step - loss: 0.1990 - val_loss: 0.6136
# Epoch 345/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step - loss: 0.1706 - val_loss: 0.6049
# Epoch 346/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 709us/step - loss: 0.1790 - val_loss: 0.6212
# Epoch 347/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 737us/step - loss: 0.1846 - val_loss: 0.6232
# Epoch 348/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 726us/step - loss: 0.1720 - val_loss: 0.6341
# Epoch 349/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step - loss: 0.1859 - val_loss: 0.6165
# Epoch 350/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step - loss: 0.1620 - val_loss: 0.6117
# Epoch 351/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step - loss: 0.1972 - val_loss: 0.6162
# Epoch 352/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 716us/step - loss: 0.1790 - val_loss: 0.6234
# Epoch 353/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 685us/step - loss: 0.1886 - val_loss: 0.6362
# Epoch 354/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step - loss: 0.1550 - val_loss: 0.6166
# Epoch 355/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 727us/step - loss: 0.2076 - val_loss: 0.6250
# Epoch 356/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 722us/step - loss: 0.1701 - val_loss: 0.6361
# Epoch 357/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 707us/step - loss: 0.1638 - val_loss: 0.6247
# Epoch 358/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step - loss: 0.2048 - val_loss: 0.6484
# Epoch 359/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 814us/step - loss: 0.1915 - val_loss: 0.6318
# Epoch 360/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step - loss: 0.1605 - val_loss: 0.6103
# Epoch 361/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step - loss: 0.1841 - val_loss: 0.6480
# Epoch 362/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 670us/step - loss: 0.2217 - val_loss: 0.6340
# Epoch 363/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 727us/step - loss: 0.1781 - val_loss: 0.6215
# Epoch 364/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step - loss: 0.1880 - val_loss: 0.6374
# Epoch 365/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 715us/step - loss: 0.1678 - val_loss: 0.6300
# Epoch 366/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 680us/step - loss: 0.1823 - val_loss: 0.6544
# Epoch 367/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step - loss: 0.1669 - val_loss: 0.6253
# Epoch 368/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step - loss: 0.1602 - val_loss: 0.6258
# Epoch 369/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step - loss: 0.1590 - val_loss: 0.6322
# Epoch 370/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 715us/step - loss: 0.1897 - val_loss: 0.6324
# Epoch 371/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 708us/step - loss: 0.1554 - val_loss: 0.6620
# Epoch 372/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step - loss: 0.1688 - val_loss: 0.6350
# Epoch 373/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 711us/step - loss: 0.1642 - val_loss: 0.6317
# Epoch 374/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 727us/step - loss: 0.1766 - val_loss: 0.6233
# Epoch 375/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 713us/step - loss: 0.1873 - val_loss: 0.6220
# Epoch 376/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 677us/step - loss: 0.1663 - val_loss: 0.6642
# Epoch 377/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step - loss: 0.1925 - val_loss: 0.6504
# Epoch 378/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 835us/step - loss: 0.1962 - val_loss: 0.6469
# Epoch 379/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step - loss: 0.1878 - val_loss: 0.6339
# Epoch 380/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 711us/step - loss: 0.1786 - val_loss: 0.6540
# Epoch 381/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 713us/step - loss: 0.1472 - val_loss: 0.6181
# Epoch 382/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step - loss: 0.1669 - val_loss: 0.6406
# Epoch 383/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step - loss: 0.1964 - val_loss: 0.6314
# Epoch 384/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step - loss: 0.1673 - val_loss: 0.6456
# Epoch 385/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step - loss: 0.1663 - val_loss: 0.6563
# Epoch 386/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step - loss: 0.1810 - val_loss: 0.6498
# Epoch 387/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 715us/step - loss: 0.1723 - val_loss: 0.6815
# Epoch 388/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step - loss: 0.1685 - val_loss: 0.6452
# Epoch 389/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step - loss: 0.1777 - val_loss: 0.6541
# Epoch 390/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step - loss: 0.1858 - val_loss: 0.6244
# Epoch 391/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 708us/step - loss: 0.1746 - val_loss: 0.6676
# Epoch 392/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step - loss: 0.1911 - val_loss: 0.6389
# Epoch 393/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step - loss: 0.1716 - val_loss: 0.6398
# Epoch 394/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step - loss: 0.1744 - val_loss: 0.6426
# Epoch 395/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step - loss: 0.1570 - val_loss: 0.6430
# Epoch 396/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 686us/step - loss: 0.1736 - val_loss: 0.6461
# Epoch 397/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 677us/step - loss: 0.1995 - val_loss: 0.6258
# Epoch 398/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step - loss: 0.1869 - val_loss: 0.6494
# Epoch 399/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step - loss: 0.1880 - val_loss: 0.6493
# Epoch 400/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step - loss: 0.1406 - val_loss: 0.6339
# Epoch 401/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step - loss: 0.1755 - val_loss: 0.6783
# Epoch 402/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step - loss: 0.2013 - val_loss: 0.6497
# Epoch 403/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 796us/step - loss: 0.1788 - val_loss: 0.6469
# Epoch 404/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 716us/step - loss: 0.1631 - val_loss: 0.6485
# Epoch 405/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step - loss: 0.1879 - val_loss: 0.6396
# Epoch 406/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 713us/step - loss: 0.1687 - val_loss: 0.6753
# Epoch 407/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 709us/step - loss: 0.1918 - val_loss: 0.6683
# Epoch 408/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - loss: 0.1760 - val_loss: 0.6314
# Epoch 409/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - loss: 0.1818 - val_loss: 0.6500
# Epoch 410/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step - loss: 0.1705 - val_loss: 0.6280
# Epoch 411/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step - loss: 0.1817 - val_loss: 0.6397
# Epoch 412/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step - loss: 0.1858 - val_loss: 0.6424
# Epoch 413/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 809us/step - loss: 0.1724 - val_loss: 0.6298
# Epoch 414/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step - loss: 0.1605 - val_loss: 0.6522
# Epoch 415/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step - loss: 0.1525 - val_loss: 0.6411
# Epoch 416/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step - loss: 0.1837 - val_loss: 0.6589
# Epoch 417/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 720us/step - loss: 0.1824 - val_loss: 0.6492
# Epoch 418/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step - loss: 0.1790 - val_loss: 0.6546
# Epoch 419/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 726us/step - loss: 0.1885 - val_loss: 0.6591
# Epoch 420/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 716us/step - loss: 0.1866 - val_loss: 0.6658
# Epoch 421/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 736us/step - loss: 0.1725 - val_loss: 0.6361
# Epoch 422/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 737us/step - loss: 0.1452 - val_loss: 0.6453
# Epoch 423/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step - loss: 0.1738 - val_loss: 0.6494
# Epoch 424/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 737us/step - loss: 0.1827 - val_loss: 0.6446
# Epoch 425/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step - loss: 0.1652 - val_loss: 0.6681
# Epoch 426/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step - loss: 0.1636 - val_loss: 0.6497
# Epoch 427/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 804us/step - loss: 0.1834 - val_loss: 0.6982
# Epoch 428/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step - loss: 0.1729 - val_loss: 0.6520
# Epoch 429/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 708us/step - loss: 0.1444 - val_loss: 0.6545
# Epoch 430/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step - loss: 0.2021 - val_loss: 0.6705
# Epoch 431/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step - loss: 0.1635 - val_loss: 0.6708
# Epoch 432/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step - loss: 0.1757 - val_loss: 0.6447
# Epoch 433/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step - loss: 0.1778 - val_loss: 0.6674
# Epoch 434/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 710us/step - loss: 0.2022 - val_loss: 0.6701
# Epoch 435/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 678us/step - loss: 0.1430 - val_loss: 0.6668
# Epoch 436/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 686us/step - loss: 0.1712 - val_loss: 0.6548
# Epoch 437/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 727us/step - loss: 0.1734 - val_loss: 0.6469
# Epoch 438/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step - loss: 0.1491 - val_loss: 0.6448
# Epoch 439/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 711us/step - loss: 0.1500 - val_loss: 0.6642
# Epoch 440/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step - loss: 0.1486 - val_loss: 0.6690
# Epoch 441/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 711us/step - loss: 0.1779 - val_loss: 0.6734
# Epoch 442/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step - loss: 0.1477 - val_loss: 0.6666
# Epoch 443/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step - loss: 0.1763 - val_loss: 0.6434
# Epoch 444/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step - loss: 0.1589 - val_loss: 0.6487
# Epoch 445/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step - loss: 0.1396 - val_loss: 0.6570
# Epoch 446/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 756us/step - loss: 0.1702 - val_loss: 0.6369
# Epoch 447/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 737us/step - loss: 0.1460 - val_loss: 0.6337
# Epoch 448/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step - loss: 0.1507 - val_loss: 0.6741
# Epoch 449/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step - loss: 0.1580 - val_loss: 0.6559
# Epoch 450/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step - loss: 0.1806 - val_loss: 0.6635
# Epoch 451/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step - loss: 0.1771 - val_loss: 0.6415
# Epoch 452/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step - loss: 0.1380 - val_loss: 0.6633
# Epoch 453/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step - loss: 0.1974 - val_loss: 0.6738
# Epoch 454/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 788us/step - loss: 0.1753 - val_loss: 0.6807
# Epoch 455/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step - loss: 0.1606 - val_loss: 0.6524
# Epoch 456/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 707us/step - loss: 0.1416 - val_loss: 0.6862
# Epoch 457/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 712us/step - loss: 0.1471 - val_loss: 0.6767
# Epoch 458/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step - loss: 0.1515 - val_loss: 0.6760
# Epoch 459/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step - loss: 0.1638 - val_loss: 0.6463
# Epoch 460/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step - loss: 0.1755 - val_loss: 0.6503
# Epoch 461/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 792us/step - loss: 0.1686 - val_loss: 0.6831
# Epoch 462/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 710us/step - loss: 0.1734 - val_loss: 0.6963
# Epoch 463/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 726us/step - loss: 0.1556 - val_loss: 0.6657
# Epoch 464/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step - loss: 0.1864 - val_loss: 0.6612
# Epoch 465/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step - loss: 0.1656 - val_loss: 0.6550
# Epoch 466/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step - loss: 0.1702 - val_loss: 0.6720
# Epoch 467/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 710us/step - loss: 0.1628 - val_loss: 0.6636
# Epoch 468/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step - loss: 0.1477 - val_loss: 0.6598
# Epoch 469/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step - loss: 0.1713 - val_loss: 0.6577
# Epoch 470/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 720us/step - loss: 0.1811 - val_loss: 0.6588
# Epoch 471/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 723us/step - loss: 0.1597 - val_loss: 0.6813
# Epoch 472/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step - loss: 0.1600 - val_loss: 0.6593
# Epoch 473/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 712us/step - loss: 0.1682 - val_loss: 0.6714
# Epoch 474/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 712us/step - loss: 0.1576 - val_loss: 0.6378
# Epoch 475/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step - loss: 0.1721 - val_loss: 0.6667
# Epoch 476/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 710us/step - loss: 0.1363 - val_loss: 0.6699
# Epoch 477/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 711us/step - loss: 0.1861 - val_loss: 0.6705
# Epoch 478/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step - loss: 0.1725 - val_loss: 0.6454
# Epoch 479/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 821us/step - loss: 0.1550 - val_loss: 0.6601
# Epoch 480/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 719us/step - loss: 0.1660 - val_loss: 0.6536
# Epoch 481/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step - loss: 0.1769 - val_loss: 0.6738
# Epoch 482/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step - loss: 0.1670 - val_loss: 0.6778
# Epoch 483/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 722us/step - loss: 0.1862 - val_loss: 0.6577
# Epoch 484/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step - loss: 0.1472 - val_loss: 0.6586
# Epoch 485/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step - loss: 0.1762 - val_loss: 0.6392
# Epoch 486/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step - loss: 0.1568 - val_loss: 0.6691
# Epoch 487/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 708us/step - loss: 0.1322 - val_loss: 0.6800
# Epoch 488/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 737us/step - loss: 0.1561 - val_loss: 0.6664
# Epoch 489/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step - loss: 0.1780 - val_loss: 0.6712
# Epoch 490/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step - loss: 0.1610 - val_loss: 0.6701
# Epoch 491/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 686us/step - loss: 0.1733 - val_loss: 0.6706
# Epoch 492/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step - loss: 0.1440 - val_loss: 0.6803
# Epoch 493/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 710us/step - loss: 0.1786 - val_loss: 0.6623
# Epoch 494/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step - loss: 0.1916 - val_loss: 0.6745
# Epoch 495/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step - loss: 0.1637 - val_loss: 0.6890
# Epoch 496/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 711us/step - loss: 0.1812 - val_loss: 0.6717
# Epoch 497/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 704us/step - loss: 0.1439 - val_loss: 0.6507
# Epoch 498/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step - loss: 0.1582 - val_loss: 0.6910
# Epoch 499/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 727us/step - loss: 0.1567 - val_loss: 0.6840
# Epoch 500/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 681us/step - loss: 0.1455 - val_loss: 0.6815
# Epoch 501/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 708us/step - loss: 0.1743 - val_loss: 0.6612
# Epoch 502/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step - loss: 0.1920 - val_loss: 0.6634
# Epoch 503/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step - loss: 0.1730 - val_loss: 0.6566
# Epoch 504/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 728us/step - loss: 0.1601 - val_loss: 0.6726
# Epoch 505/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 720us/step - loss: 0.1572 - val_loss: 0.6644
# Epoch 506/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step - loss: 0.1498 - val_loss: 0.6528
# Epoch 507/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 716us/step - loss: 0.1470 - val_loss: 0.6750
# Epoch 508/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 802us/step - loss: 0.1514 - val_loss: 0.6591
# Epoch 509/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step - loss: 0.1480 - val_loss: 0.6731
# Epoch 510/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 679us/step - loss: 0.1728 - val_loss: 0.6790
# Epoch 511/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step - loss: 0.1423 - val_loss: 0.6542
# Epoch 512/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step - loss: 0.1526 - val_loss: 0.6779
# Epoch 513/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 689us/step - loss: 0.1654 - val_loss: 0.6678
# Epoch 514/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step - loss: 0.1635 - val_loss: 0.6446
# Epoch 515/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 715us/step - loss: 0.1662 - val_loss: 0.6630
# Epoch 516/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 707us/step - loss: 0.1602 - val_loss: 0.6860
# Epoch 517/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 671us/step - loss: 0.1690 - val_loss: 0.6876
# Epoch 518/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 688us/step - loss: 0.1368 - val_loss: 0.6761
# Epoch 519/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 710us/step - loss: 0.1440 - val_loss: 0.6813
# Epoch 520/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step - loss: 0.1627 - val_loss: 0.6814
# Epoch 521/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step - loss: 0.1675 - val_loss: 0.6881
# Epoch 522/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 685us/step - loss: 0.1924 - val_loss: 0.6808
# Epoch 523/1000
# ...
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 708us/step - loss: 0.1024 - val_loss: 0.7045
# Epoch 828/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 758us/step - loss: 0.1230 - val_loss: 0.7604
# Epoch 829/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step - loss: 0.1196 - val_loss: 0.7740
# Epoch 830/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 840us/step - loss: 0.1226 - val_loss: 0.7392
# Epoch 831/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 710us/step - loss: 0.1504 - val_loss: 0.7199
# Epoch 832/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 719us/step - loss: 0.1464 - val_loss: 0.7696
# Epoch 833/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step - loss: 0.1472 - val_loss: 0.7365
# Epoch 834/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 710us/step - loss: 0.1406 - val_loss: 0.7731
# Epoch 835/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 780us/step - loss: 0.1405 - val_loss: 0.7790
# Epoch 836/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 727us/step - loss: 0.1426 - val_loss: 0.7339
# Epoch 837/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 733us/step - loss: 0.1147 - val_loss: 0.7438
# Epoch 838/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step - loss: 0.1361 - val_loss: 0.7544
# Epoch 839/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step - loss: 0.1415 - val_loss: 0.7868
# Epoch 840/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 741us/step - loss: 0.1265 - val_loss: 0.7425
# Epoch 841/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 686us/step - loss: 0.1190 - val_loss: 0.7700
# Epoch 842/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step - loss: 0.1602 - val_loss: 0.7421
# Epoch 843/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step - loss: 0.1382 - val_loss: 0.7497
# Epoch 844/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - loss: 0.1409 - val_loss: 0.7511
# Epoch 845/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step - loss: 0.1153 - val_loss: 0.7349
# Epoch 846/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step - loss: 0.1290 - val_loss: 0.7583
# Epoch 847/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step - loss: 0.1193 - val_loss: 0.7542
# Epoch 848/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step - loss: 0.1351 - val_loss: 0.7481
# Epoch 849/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step - loss: 0.1513 - val_loss: 0.7356
# Epoch 850/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step - loss: 0.1206 - val_loss: 0.7361
# Epoch 851/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 720us/step - loss: 0.1174 - val_loss: 0.7510
# Epoch 852/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 707us/step - loss: 0.1194 - val_loss: 0.7362
# Epoch 853/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step - loss: 0.1201 - val_loss: 0.7473
# Epoch 854/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 733us/step - loss: 0.1101 - val_loss: 0.8268
# Epoch 855/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 723us/step - loss: 0.1355 - val_loss: 0.7494
# Epoch 856/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 803us/step - loss: 0.1202 - val_loss: 0.7278
# Epoch 857/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 726us/step - loss: 0.1285 - val_loss: 0.7437
# Epoch 858/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 728us/step - loss: 0.1334 - val_loss: 0.7408
# Epoch 859/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 723us/step - loss: 0.1386 - val_loss: 0.7637
# Epoch 860/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 707us/step - loss: 0.1295 - val_loss: 0.7445
# Epoch 861/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 710us/step - loss: 0.1123 - val_loss: 0.7286
# Epoch 862/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step - loss: 0.1224 - val_loss: 0.7547
# Epoch 863/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 727us/step - loss: 0.1238 - val_loss: 0.7573
# Epoch 864/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 709us/step - loss: 0.1207 - val_loss: 0.7344
# Epoch 865/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 841us/step - loss: 0.1141 - val_loss: 0.7449
# Epoch 866/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step - loss: 0.1499 - val_loss: 0.7465
# Epoch 867/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step - loss: 0.1357 - val_loss: 0.7389
# Epoch 868/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 708us/step - loss: 0.1375 - val_loss: 0.7572
# Epoch 869/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 715us/step - loss: 0.1300 - val_loss: 0.7519
# Epoch 870/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step - loss: 0.1179 - val_loss: 0.7490
# Epoch 871/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step - loss: 0.1320 - val_loss: 0.7516
# Epoch 872/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 816us/step - loss: 0.1332 - val_loss: 0.7371
# Epoch 873/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step - loss: 0.1093 - val_loss: 0.7628
# Epoch 874/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 710us/step - loss: 0.1304 - val_loss: 0.7508
# Epoch 875/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - loss: 0.1115 - val_loss: 0.7848
# Epoch 876/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step - loss: 0.1191 - val_loss: 0.7506
# Epoch 877/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step - loss: 0.1217 - val_loss: 0.7444
# Epoch 878/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 715us/step - loss: 0.1303 - val_loss: 0.8016
# Epoch 879/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 716us/step - loss: 0.1322 - val_loss: 0.7489
# Epoch 880/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step - loss: 0.1374 - val_loss: 0.7620
# Epoch 881/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 713us/step - loss: 0.1063 - val_loss: 0.7117
# Epoch 882/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 710us/step - loss: 0.1504 - val_loss: 0.7658
# Epoch 883/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 733us/step - loss: 0.1128 - val_loss: 0.7448
# Epoch 884/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step - loss: 0.1263 - val_loss: 0.7761
# Epoch 885/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 735us/step - loss: 0.1210 - val_loss: 0.7757
# Epoch 886/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 794us/step - loss: 0.1208 - val_loss: 0.7490
# Epoch 887/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 706us/step - loss: 0.1267 - val_loss: 0.7808
# Epoch 888/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 706us/step - loss: 0.1565 - val_loss: 0.7333
# Epoch 889/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 730us/step - loss: 0.1545 - val_loss: 0.7415
# Epoch 890/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step - loss: 0.1244 - val_loss: 0.7620
# Epoch 891/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 837us/step - loss: 0.1314 - val_loss: 0.7507
# Epoch 892/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 720us/step - loss: 0.1249 - val_loss: 0.7729
# Epoch 893/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 726us/step - loss: 0.1132 - val_loss: 0.7498
# Epoch 894/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 709us/step - loss: 0.1303 - val_loss: 0.7633
# Epoch 895/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 756us/step - loss: 0.1261 - val_loss: 0.7728
# Epoch 896/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 716us/step - loss: 0.1310 - val_loss: 0.7306
# Epoch 897/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step - loss: 0.1225 - val_loss: 0.7382
# Epoch 898/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 706us/step - loss: 0.1534 - val_loss: 0.7986
# Epoch 899/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step - loss: 0.1195 - val_loss: 0.7674
# Epoch 900/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 756us/step - loss: 0.1277 - val_loss: 0.7647
# Epoch 901/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step - loss: 0.1259 - val_loss: 0.7542
# Epoch 902/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 710us/step - loss: 0.1652 - val_loss: 0.7315
# Epoch 903/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step - loss: 0.1156 - val_loss: 0.7331
# Epoch 904/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 722us/step - loss: 0.1060 - val_loss: 0.7656
# Epoch 905/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 789us/step - loss: 0.1220 - val_loss: 0.7609
# Epoch 906/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 810us/step - loss: 0.1044 - val_loss: 0.7634
# Epoch 907/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 716us/step - loss: 0.1428 - val_loss: 0.7393
# Epoch 908/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step - loss: 0.1028 - val_loss: 0.7273
# Epoch 909/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 728us/step - loss: 0.1169 - val_loss: 0.7524
# Epoch 910/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step - loss: 0.1493 - val_loss: 0.7547
# Epoch 911/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 733us/step - loss: 0.1277 - val_loss: 0.7679
# Epoch 912/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 833us/step - loss: 0.1225 - val_loss: 0.7816
# Epoch 913/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step - loss: 0.1306 - val_loss: 0.7631
# Epoch 914/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 756us/step - loss: 0.1307 - val_loss: 0.7906
# Epoch 915/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 720us/step - loss: 0.1156 - val_loss: 0.7721
# Epoch 916/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step - loss: 0.1044 - val_loss: 0.7699
# Epoch 917/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step - loss: 0.1354 - val_loss: 0.7814
# Epoch 918/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 741us/step - loss: 0.1370 - val_loss: 0.7627
# Epoch 919/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step - loss: 0.1121 - val_loss: 0.7758
# Epoch 920/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 784us/step - loss: 0.1302 - val_loss: 0.7509
# Epoch 921/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step - loss: 0.1284 - val_loss: 0.7318
# Epoch 922/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step - loss: 0.1181 - val_loss: 0.7406
# Epoch 923/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 721us/step - loss: 0.1003 - val_loss: 0.7710
# Epoch 924/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 724us/step - loss: 0.1213 - val_loss: 0.7902
# Epoch 925/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - loss: 0.1154 - val_loss: 0.7568
# Epoch 926/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 700us/step - loss: 0.1201 - val_loss: 0.7698
# Epoch 927/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 814us/step - loss: 0.1182 - val_loss: 0.7372
# Epoch 928/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step - loss: 0.1219 - val_loss: 0.7730
# Epoch 929/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - loss: 0.1026 - val_loss: 0.7606
# Epoch 930/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 723us/step - loss: 0.1037 - val_loss: 0.7843
# Epoch 931/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 719us/step - loss: 0.1181 - val_loss: 0.7542
# Epoch 932/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step - loss: 0.1125 - val_loss: 0.7800
# Epoch 933/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - loss: 0.1115 - val_loss: 0.7383
# Epoch 934/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 794us/step - loss: 0.1176 - val_loss: 0.7566
# Epoch 935/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step - loss: 0.1140 - val_loss: 0.7597
# Epoch 936/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 706us/step - loss: 0.1305 - val_loss: 0.7652
# Epoch 937/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 707us/step - loss: 0.1305 - val_loss: 0.7615
# Epoch 938/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step - loss: 0.1265 - val_loss: 0.7690
# Epoch 939/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step - loss: 0.1233 - val_loss: 0.7846
# Epoch 940/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - loss: 0.1358 - val_loss: 0.7558
# Epoch 941/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step - loss: 0.1220 - val_loss: 0.7730
# Epoch 942/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 790us/step - loss: 0.1187 - val_loss: 0.7979
# Epoch 943/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 720us/step - loss: 0.1300 - val_loss: 0.7736
# Epoch 944/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - loss: 0.1374 - val_loss: 0.7506
# Epoch 945/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step - loss: 0.1387 - val_loss: 0.7499
# Epoch 946/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step - loss: 0.0959 - val_loss: 0.7667
# Epoch 947/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step - loss: 0.1203 - val_loss: 0.7623
# Epoch 948/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step - loss: 0.1682 - val_loss: 0.7409
# Epoch 949/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 709us/step - loss: 0.1196 - val_loss: 0.7554
# Epoch 950/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 817us/step - loss: 0.1179 - val_loss: 0.7657
# Epoch 951/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 708us/step - loss: 0.1178 - val_loss: 0.7546
# Epoch 952/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step - loss: 0.1134 - val_loss: 0.7503
# Epoch 953/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 737us/step - loss: 0.1319 - val_loss: 0.7834
# Epoch 954/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 733us/step - loss: 0.1136 - val_loss: 0.7471
# Epoch 955/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 723us/step - loss: 0.1280 - val_loss: 0.7846
# Epoch 956/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 722us/step - loss: 0.1230 - val_loss: 0.7630
# Epoch 957/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 724us/step - loss: 0.1226 - val_loss: 0.7563
# Epoch 958/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 815us/step - loss: 0.1142 - val_loss: 0.7813
# Epoch 959/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step - loss: 0.1258 - val_loss: 0.7759
# Epoch 960/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step - loss: 0.1204 - val_loss: 0.7961
# Epoch 961/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 692us/step - loss: 0.1359 - val_loss: 0.7721
# Epoch 962/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step - loss: 0.1232 - val_loss: 0.7588
# Epoch 963/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step - loss: 0.0971 - val_loss: 0.7716
# Epoch 964/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 735us/step - loss: 0.1168 - val_loss: 0.7970
# Epoch 965/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step - loss: 0.1435 - val_loss: 0.7676
# Epoch 966/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 801us/step - loss: 0.1156 - val_loss: 0.7732
# Epoch 967/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step - loss: 0.1113 - val_loss: 0.7642
# Epoch 968/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 728us/step - loss: 0.1357 - val_loss: 0.7708
# Epoch 969/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 736us/step - loss: 0.1314 - val_loss: 0.7393
# Epoch 970/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step - loss: 0.1241 - val_loss: 0.7732
# Epoch 971/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 720us/step - loss: 0.1138 - val_loss: 0.7992
# Epoch 972/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 822us/step - loss: 0.1352 - val_loss: 0.7585
# Epoch 973/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step - loss: 0.1462 - val_loss: 0.8234
# Epoch 974/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step - loss: 0.1361 - val_loss: 0.7694
# Epoch 975/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 772us/step - loss: 0.1181 - val_loss: 0.8002
# Epoch 976/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 684us/step - loss: 0.1194 - val_loss: 0.7793
# Epoch 977/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step - loss: 0.1448 - val_loss: 0.8393
# Epoch 978/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 716us/step - loss: 0.0993 - val_loss: 0.7683
# Epoch 979/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 709us/step - loss: 0.1043 - val_loss: 0.7940
# Epoch 980/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 733us/step - loss: 0.1143 - val_loss: 0.7497
# Epoch 981/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 720us/step - loss: 0.1197 - val_loss: 0.7631
# Epoch 982/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 689us/step - loss: 0.1378 - val_loss: 0.8103
# Epoch 983/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 809us/step - loss: 0.1113 - val_loss: 0.7712
# Epoch 984/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 699us/step - loss: 0.0950 - val_loss: 0.7844
# Epoch 985/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 710us/step - loss: 0.1009 - val_loss: 0.7829
# Epoch 986/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step - loss: 0.1239 - val_loss: 0.7830
# Epoch 987/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step - loss: 0.1226 - val_loss: 0.7610
# Epoch 988/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 713us/step - loss: 0.1288 - val_loss: 0.7528
# Epoch 989/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 714us/step - loss: 0.1253 - val_loss: 0.8182
# Epoch 990/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 723us/step - loss: 0.1546 - val_loss: 0.7685
# Epoch 991/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 835us/step - loss: 0.1298 - val_loss: 0.7687
# Epoch 992/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 712us/step - loss: 0.1106 - val_loss: 0.8071
# Epoch 993/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step - loss: 0.1241 - val_loss: 0.7905
# Epoch 994/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step - loss: 0.1147 - val_loss: 0.7744
# Epoch 995/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 736us/step - loss: 0.1052 - val_loss: 0.7889
# Epoch 996/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step - loss: 0.1112 - val_loss: 0.7992
# Epoch 997/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 817us/step - loss: 0.1279 - val_loss: 0.7626
# Epoch 998/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 698us/step - loss: 0.1100 - val_loss: 0.7801
# Epoch 999/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step - loss: 0.1267 - val_loss: 0.7721
# Epoch 1000/1000
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 710us/step - loss: 0.1256 - val_loss: 0.7683

# %% [markdown]
# ## Evaluate the Performance of the Model

# %%
# Evaluate the model
loss = model.evaluate(X_test, y_test, verbose=1)
print(f'Loss on test data: {loss:.4f}')

# Make predictions
y_pred = model.predict(X_test)

# Inverse transform predictions and true values
y_test_inv = scaler_y.inverse_transform(y_test)
y_pred_inv = scaler_y.inverse_transform(y_pred)

# Calculate metrics
mae_longitude = mean_absolute_error(y_test_inv[:, 0], y_pred_inv[:, 0])
mae_latitude = mean_absolute_error(y_test_inv[:, 1], y_pred_inv[:, 1])
mse_longitude = mean_squared_error(y_test_inv[:, 0], y_pred_inv[:, 0])
mse_latitude = mean_squared_error(y_test_inv[:, 1], y_pred_inv[:, 1])
rmse_longitude = np.sqrt(mse_longitude)
rmse_latitude = np.sqrt(mse_latitude)
r2_longitude = r2_score(y_test_inv[:, 0], y_pred_inv[:, 0])
r2_latitude = r2_score(y_test_inv[:, 1], y_pred_inv[:, 1])

print(f'Mean Absolute Error for Longitude: {mae_longitude:.2f}')
print(f'Mean Absolute Error for Latitude: {mae_latitude:.2f}')
print(f'Mean Squared Error for Longitude: {mse_longitude:.2f}')
print(f'Mean Squared Error for Latitude: {mse_latitude:.2f}')
print(f'Root Mean Squared Error for Longitude: {rmse_longitude:.2f}')
print(f'Root Mean Squared Error for Latitude: {rmse_latitude:.2f}')
print(f'R-squared for Longitude: {r2_longitude:.2f}')
print(f'R-squared for Latitude: {r2_latitude:.2f}')
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 689us/step - loss: 0.7001
# Loss on test data: 0.5991
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Mean Absolute Error for Longitude: 6.43
# Mean Absolute Error for Latitude: 6.17
# Mean Squared Error for Longitude: 78.17
# Mean Squared Error for Latitude: 78.99
# Root Mean Squared Error for Longitude: 8.84
# Root Mean Squared Error for Latitude: 8.89
# R-squared for Longitude: 0.86
# R-squared for Latitude: 0.09

# %% [markdown]
# ## Saving the Model

# %%
# Save the model
model.save('../models/NN_Model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
